# %%
from dotenv import load_dotenv
import os
load_dotenv()

from langchain_openai import ChatOpenAI
from langchain_openai import  OpenAIEmbeddings

llm = ChatOpenAI(
    model="",
    temperature=0.3,
    base_url="https://arvancloudai.ir/gateway/models/GPT-4.1-Mini/9OsdnLiTU_iiXBZwpOK3QzWFW__ES_uGi7PC7EgYnYjuy3VfT4wF1Q73FmlXRh35hbgUWSFYxHRQ1_bwbm6kO58L2TFGJf8JJxv---mUmUHRhMLNZrXkaUsEzftOvnK__6KmJnVF3HLhy_jR3zqUf6l-Lfp3TSMuKL4rs3S7wor8dqYBpcm-GTvr5MmrCupgVGuinj7ERK-PrM6kJBtCh1kOmMISB1zijOWLcR9QuLN__4et7J3JiDKqkXyhPA/v1",
    api_key=os.getenv("ARVAN_API_KEY"),
)

embeddings_arvan = OpenAIEmbeddings(
    # model="text-embedding-3-large",
    # api_key=os.getenv("OPENAI_KEY"),
    # base_url=os.getenv("BASE_URL"),
    model="Embedding-3-Large",
    api_key=os.getenv("ARVAN_API_KEY"),
    base_url="https://arvancloudai.ir/gateway/models/Embedding-3-Large/Ua02cuX3b4aq8ZhgyR0C3OFAg7O0cneTH-zojCzHpg7mPMJN1zUMbF0s1eA0OLwrGk9alnkvqo3fGcBkLjezBMgpGGqy44D8G2E3nLODf6KCf3HzComW4TssHOGKE9LWhdjlWjKJZfrBlGePdsdmZcMO1C1Je149W_3Zwjwpy-mB54Gbk_x_xnVRmc7Us04Q1UaAmTwG8EqOVJ5TeRPZYzOBtVCldBzwDvV6uYRjb9z1lxzh6oaSKJbd9k-K8VlczjhGbwX72ys/v1"
)

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",
    api_key=os.getenv("OPENAI_KEY"),
    base_url=os.getenv("BASE_URL"),
)

import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
llm.invoke("hello")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 8, 'total_tokens': 18, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 7, 'engine_ttft_ms': 23, 'engine_ttlt_ms': 96, 'pre_inference_ms': 107, 'service_tbt_ms': 17, 'service_ttft_ms': 570, 'service_ttlt_ms': 741, 'total_duration_ms': 636, 'user_visible_ttft_ms': 462}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_20b2a3c29b', 'id': 'chatcmpl-E7DUjDtxbwIvcTllXHAdG9RnXQYss', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fb17f-8425-7b40-b364-13c4440686a5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 10, 'total_tokens': 18, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(embeddings.embed_query("hello"))
print(embeddings_arvan.embed_query("hello"))
# Out:
# [-0.024627685546875, -0.0075836181640625, 0.003971099853515625, 0.006008148193359375, 0.0050811767578125, 0.00019347667694091797, -0.00644683837890625, 0.052490234375, 0.009613037109375, 0.056488037109375, -0.00433349609375, -0.0212249755859375, -0.021575927734375, -0.0103912353515625, -0.01788330078125, 0.0201416015625, 0.0240936279296875, 0.0059814453125, 0.01508331298828125, -0.0118408203125, 0.01064300537109375, -0.00814056396484375, 0.0011053085327148438, 0.03509521484375, 0.01006317138671875, 0.0312042236328125, -0.0208740234375, -0.0172576904296875, -0.049224853
, 0.017608642578125, 0.0228118896484375, -0.00879669189453125, 0.03411865234375, 0.0220184326171875, 0.01334381103515625, 0.033447265625, -0.0213775634765625, -0.00571441650390625, -0.0139923095703125, -0.0019741058349609375, 0.046295166015625, -0.029571533203125, 0.0384521484375, -0.005229949951171875, 0.00986480712890625, 0.0016107559204101562, 0.032257080078125, 0.019622802734375, 0.040191650390625, -0.006011962890625, -0.00975799560546875, -0.01 ...
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File C:\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\openai\_base_client.py:1065, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1064 try:
# -> 1065     response = self._send_request(
#    1066         request,
#    1067         stream=stream or self._should_stream_response_body(request=request),
#    1068         **kwargs,
#    1069     )
#    1070 except timeout_exceptions() as err:
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\openai\_client.py:483, in OpenAI._send_request(self, request, stream, **kwargs)
#     475 @override
#     476 def _send_request(
#     477     self,
#    (...)    481     **kwargs: Unpack[HttpxSendArgs],
#     482 ) -> httpx.Response:
# --> 483     response = self._send_with_auth_retry(request, stream=stream, **kwargs)
#     484     if self._provider_runtime is not None and self._provider_runtime.normalize_response is not None:
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\openai\_client.py:461, in OpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     459         used_workload_identity_auth = True
# --> 461 response = super()._send_request(request, stream=stream, **kwargs)
#     462 if (
#     463     response.status_code == 401
#     464     and self._workload_identity_auth is not None
#     465     and used_workload_identity_auth
#     466     and not retried
#     467 ):
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\openai\_base_client.py:990, in SyncAPIClient._send_request(self, request, stream, **kwargs)
#     983 def _send_request(
#     984     self,
#     985     request: httpx.Request,
#    (...)    988     **kwargs: Unpack[HttpxSendArgs],
#     989 ) -> httpx.Response:
# --> 990     return self._client.send(request, stream=stream, **kwargs)
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File C:\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 print(embeddings.embed_query("hello"))
# ----> 2 print(embeddings_arvan.embed_query("hello"))
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\langchain_openai\embeddings\base.py:805, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     795 """Call out to OpenAI's embedding endpoint for embedding query text.
#     796
#     797 Args:
#    (...)    802     Embedding for the text.
#     803 """
#     804 self._ensure_sync_client_available()
# --> 805 return self.embed_documents([text], **kwargs)[0]
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\langchain_openai\embeddings\base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\langchain_openai\embeddings\base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\openai\_base_client.py:1360, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1351     warnings.warn(
#    1352         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1353         "Please pass raw bytes via the `content` parameter instead.",
#    1354         DeprecationWarning,
#    1355         stacklevel=2,
#    1356     )
#    1357 opts = FinalRequestOptions.construct(
#    1358     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1359 )
# -> 1360 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\kave\Desktop\app-ravis-costumers\hybrid-rag-system\venv\Lib\site-packages\openai\_base_client.py:1100, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1097         continue
#    1099     log.debug("Raising connection error")
# -> 1100     raise APIConnectionError(request=request) from err
#    1102 log.debug(
#    1103     'HTTP Response: %s %s "%i %s" %s',
#    1104     request.method,
#    (...)   1108     response.headers,
#    1109 )
#    1110 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.
